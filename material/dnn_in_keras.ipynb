# %% [markdown]
# # 모듈 임포팅

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

import time

# %%
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense

# %% [markdown]
# # 디바이스

# %% [markdown]
# ## 리스트 보기

# %%
from tensorflow.python.client import device_lib
print(tf.test.gpu_device_name())
# Out:
# /device:GPU:0

# %% [markdown]
# ## NVIDIA GPU 상태 보기

# %%
# !nvidia-smi
# Out:
# Tue Aug 13 04:11:36 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 410.79       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   59C    P0    29W /  70W |    129MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Keras DNN 최소 코드

# %% [markdown]
# # 데이터 준비
#
# 1차원 데이터 x와 x**2의 1차원 데이타 y

# %%
import numpy as np

x = np.arange(-1,1,0.01)
y = x**2

plt.scatter(x,y)

# %%
print(len(x))
print(x.shape)
# Out:
# 200
# (200,)

# %% [markdown]
# ## 최소 코드
#
# 아래의 코드는 최소 코드.

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense

import time


# 모델 정의
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,) ))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


# 컴파일 : 모델 + optimizer + loss
model.compile(optimizer="SGD", loss="mse")


# 학습
model.fit(x, y, epochs=1000, verbose=0, batch_size=20)


# 예측
y_ = model.predict(x)


# 결과 그래프로 보기
plt.scatter(x,y) # 정답
plt.scatter(x,y_,color='r') # 결과
plt.show()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0814 11:20:32.476634 139865081911168 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %% [markdown]
# # Keras DNN 최소 코드에 기본 정도만 추가
#
# 최소는 아니고, 이정도는 매번 사용하는 코드

# %% [markdown]
# ## model.evaluate() - 성능 평가하기

# %%
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense


model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,) ))
model.add(Dense(10, activation='tanh' ))
model.add(Dense(1))


#model.compile(optimizer="SGD", loss="mse")
model.compile(optimizer="SGD", loss="mse", metrics=["mse"])


model.fit(x, y, epochs=1000, verbose=0, batch_size=20)

loss, mse = model.evaluate(x, y) # ADD
print("loss=",loss) # ADD
print("mse=",mse) # ADD


y_ = model.predict(x)


plt.scatter(x,y)
plt.scatter(x,y_,color='r')
plt.show()
# Out:
# 200/200 [==============================] - 0s 166us/sample - loss: 0.0010 - mean_squared_error: 0.0010
# loss= 0.0010450332053005696
# mse= 0.0010450332

# %% [markdown]
# 출력에 loss와 mse가 추가되었다.

# %% [markdown]
# ## 테스트셋으로 평가하기
#
# 데이터를 train과 test으로 나누어 준비한다.

# %%
x = np.arange(-1,1,0.01)
np.random.shuffle(x)
y = x**2

split_index = int(x.shape[0]*0.6)

train_x, test_x = x[:split_index], x[split_index:]
train_y, test_y = y[:split_index], y[split_index:]

plt.scatter(train_x,train_y)
plt.scatter(test_x,test_y)
plt.show()

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])


# model.fit(x, y, epochs=1000, verbose=0, batch_size=20)
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)


# loss, mse = model.evaluate(x, y)
loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


# y_ = model.predict(x)
y_ = model.predict(test_x)

# plt.scatter(x,y)
plt.scatter(test_x,test_y)
# plt.scatter(x,y_,color='r')
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# 80/80 [==============================] - 0s 393us/sample - loss: 0.0021 - mean_squared_error: 0.0021
# loss= 0.0020954911364242435
# mse= 0.0020954912

# %% [markdown]
# train_x, train_y로 학습하였고,
# evaluate()와 predict()에는 test_x, test_y를 사용하였다.
#
# 그려진 그림을 보면 test_x의 점사이에 빈 간격이 보인다. 그 간격이 train_x에 해당한다.

# %% [markdown]
# ## Base Model 결과 저장
#
# 이후 비교를 위해 그래프를 저장해 둔다.

# %%
plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.savefig("base_result.png")

from IPython.display import Image
display(Image("base_result.png"))

# %% [markdown]
# ## 학습 시간을 출력

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])

start_time = time.time() # ADD
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time)) # ADD 
    

loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# elapsed : 11.369201421737671
# 80/80 [==============================] - 0s 334us/sample - loss: 0.0037 - mean_squared_error: 0.0037
# loss= 0.003730401583015919
# mse= 0.0037304014

# %% [markdown]
# elapsed로 경과된 시간이 초 단위로 보인다.

# %% [markdown]
# ## model.summary() 네트웤 모양 보기

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary() # ADD

start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))


y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 11.479902982711792

# %% [markdown]
# 네트웤의 모양이 보인다.
#
# 노드 10개, 10개를 갖는 은닉층 2개가 있다.
#
#
# 모든 레이어는 activation(w\*x+b) 의 형태로,
#
# 첫 번 째 은닉층은 20개( = ((1+1)\*10) = (입력수+1)\*10)의 웨이트를,
#
# 두 번 째 은닉층은 110개( = ( (10+1)\*10) )의 웨이트가 있다..

# %% [markdown]
# # Keras DNN Template
#
# 본 실습에 사용되는 코든 코드의 템플릿.

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense

import time


# 모델 정의
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


# 모델 컴파일
model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


# 학습
start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))


# 평가
loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


# 예측
y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 11.414329528808594
# 80/80 [==============================] - 0s 371us/sample - loss: 0.0029 - mean_squared_error: 0.0029
# loss= 0.002885219920426607
# mse= 0.0028852199

# %% [markdown]
# # layer 수

# %% [markdown]
# ## 히든 레이어를 1개 만

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
# model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


# base 모델의 결과
display(Image("base_result.png")) # ADD

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 10.986373901367188
# 80/80 [==============================] - 0s 367us/sample - loss: 0.0038 - mean_squared_error: 0.0038
# loss= 0.003791116876527667
# mse= 0.0037911169

# %% [markdown]
# ## 히든레이어 없을 때

# %%
from tensorflow.keras.layers import Input

model = keras.Sequential()
model.add(Input((1,)))
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
# model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


# base 모델의 결과
display(Image("base_result.png")) # ADD

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 10.284699440002441
# 80/80 [==============================] - 0s 362us/sample - loss: 0.0976 - mean_squared_error: 0.0976
# loss= 0.09763804078102112
# mse= 0.09763804

# %% [markdown]
# 히든 레이어가 없을 경우 학습되지 않는다.

# %% [markdown]
# ## 히든 레이어를 3개로

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


display(Image("base_result.png"))

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_22 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_23 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_24 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_25 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 251
# Trainable params: 251
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 12.270071744918823
# 80/80 [==============================] - 0s 436us/sample - loss: 0.0025 - mean_squared_error: 0.0025
# loss= 0.002545514237135649
# mse= 0.0025455144

# %% [markdown]
# 3개로 증가해도 별 차이 없다.

# %% [markdown]
# ## 히든 레이어를 5개로

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


display(Image("base_result.png"))

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_26 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_27 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_28 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_29 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_30 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_31 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 471
# Trainable params: 471
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 13.36528491973877
# 80/80 [==============================] - 0s 520us/sample - loss: 7.6953e-04 - mean_squared_error: 7.6953e-04
# loss= 0.0007695318665355444
# mse= 0.0007695319

# %% [markdown]
# 5개로 증가했을 때 살짝 좋은 듯 하다.

# %% [markdown]
# ## 히든 레이어를 10개로

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


display(Image("base_result.png"))

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_32 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_33 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_34 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_35 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_36 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_37 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_38 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_39 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_40 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_41 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_42 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 1,021
# Trainable params: 1,021
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 16.1487820148468
# 80/80 [==============================] - 0s 671us/sample - loss: 1.4170e-04 - mean_squared_error: 1.4170e-04
# loss= 0.00014170200738590212
# mse= 0.00014170201

# %% [markdown]
# 10개로 했을 때 좋아진 차이가 보인다.

# %% [markdown]
# # node 수

# %% [markdown]
# ## node 수를 작게

# %%
model = keras.Sequential()
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
# model.add(Dense(10, activation='tanh'))
model.add(Dense(5, activation='tanh', input_shape=(1,)))
model.add(Dense(5, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


display(Image("base_result.png"))

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_43 (Dense)             (None, 5)                 10
# _________________________________________________________________
# dense_44 (Dense)             (None, 5)                 30
# _________________________________________________________________
# dense_45 (Dense)             (None, 1)                 6
# =================================================================
# Total params: 46
# Trainable params: 46
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 11.902321815490723
# 80/80 [==============================] - 0s 505us/sample - loss: 0.0015 - mean_squared_error: 0.0015
# loss= 0.0015150631312280892
# mse= 0.0015150632

# %% [markdown]
# 5개 노드의 경우 살짝 차이가 난다.

# %% [markdown]
# ## 노드 수를 아주 작게

# %%
model = keras.Sequential()
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
# model.add(Dense(10, activation='tanh'))
model.add(Dense(2, activation='tanh', input_shape=(1,)))
model.add(Dense(2, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


display(Image("base_result.png"))

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_46 (Dense)             (None, 2)                 4
# _________________________________________________________________
# dense_47 (Dense)             (None, 2)                 6
# _________________________________________________________________
# dense_48 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 13
# Trainable params: 13
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 12.028403282165527
# 80/80 [==============================] - 0s 567us/sample - loss: 0.0154 - mean_squared_error: 0.0154
# loss= 0.015350454673171043
# mse= 0.015350455

# %% [markdown]
# 2개의 경우 차이가 커 보인다.

# %% [markdown]
# ## 노드 수가 1개

# %%
model = keras.Sequential()
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
# model.add(Dense(10, activation='tanh'))
model.add(Dense(1, activation='tanh', input_shape=(1,)))
model.add(Dense(1, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


display(Image("base_result.png"))

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_49 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_50 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_51 (Dense)             (None, 1)                 2
# =================================================================
# Total params: 6
# Trainable params: 6
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 11.956905126571655
# 80/80 [==============================] - 0s 582us/sample - loss: 0.0977 - mean_squared_error: 0.0977
# loss= 0.09765801876783371
# mse= 0.09765802

# %% [markdown]
# 1개의 경우 거의 학습이 되지 않는다.

# %% [markdown]
# # 학습 추가 진행

# %% [markdown]
# 모델은 그대로 두고 데이터만 sin 데이터로 변경한다.

# %%
def get_sin_data(start=0, end=10, step=0.1):
  x = np.arange(start,end,step)
  np.random.shuffle(x)
  y = np.sin(x)

  split_index = int(x.shape[0]*0.6)

  train_x, test_x = x[:split_index], x[split_index:]
  train_y, test_y = y[:split_index], y[split_index:]

  return (train_x, train_y), (test_x, test_y)

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

plt.scatter(train_x,train_y)
plt.show()

plt.scatter(test_x,test_y,color="r")
plt.show()

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_52 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_53 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_54 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 7.029408693313599
# 40/40 [==============================] - 0s 1ms/sample - loss: 0.1624 - mean_squared_error: 0.1624
# loss= 0.16241912245750428
# mse= 0.16241913

# %% [markdown]
# 학습이 충분히 되지 않은 듯 하다.

# %% [markdown]
# ## 추가 학습

# %%
def fit_one_more(model, train_x, train_y, test_x, test_y, batch_size=20):

  start_time = time.time()
  model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=batch_size)
  print("elapsed : {}".format(time.time() - start_time))    

  y_ = model.predict(test_x)

  plt.scatter(test_x,test_y)
  plt.scatter(test_x,y_,color='r')
  plt.show()

def fit_n_times(model, train_x, train_y, test_x, test_y, n):
  
  for i in range(n):
    print("{} times fitting".format(i))
    fit_one_more(model, train_x, train_y, test_x, test_y)

# %%
fit_n_times(model, train_x, train_y, test_x, test_y, 10)
# Out:
# 0 times fitting
# elapsed : 6.860821008682251
# 1 times fitting
# elapsed : 6.830053806304932
# 2 times fitting
# elapsed : 6.776483535766602
# 3 times fitting
# elapsed : 6.757455110549927
# 4 times fitting
# elapsed : 6.848926305770874
# 5 times fitting
# elapsed : 6.840904951095581
# 6 times fitting
# elapsed : 6.881314039230347
# 7 times fitting
# elapsed : 6.782005310058594
# 8 times fitting
# elapsed : 6.755645513534546
# 9 times fitting
# elapsed : 6.758832693099976

# %% [markdown]
# 학습이 더 진행되면서 거의 완벽하게 학습된 것을 볼 수 있다.

# %% [markdown]
# # model.fit()의 batch_size
#
# batch_size는 GPU와 관련된 옵션이다.
#
# 한번에 GPU에 보내는 데이터의 수이다.
#
# <br>
#
# batch_size가 1일 경우 1개를 보내고, 1개의 결과를 받고, 1번 웨이트를 업데이트 한다.
#
# batch_size가 10일 경우 10개를 보내고, 10개의 결과를 한 번에 받고, 1번 웨이트를 업데이트 한다.
#
# <br>
#
# GPU는 보통 수천개의 코어를 가지고 있다. 동시에 꽤 많은 연산을 처리할 수 있다. 그런데 데이터가 적으면 대부분은 사용하지 못하고 일부만 연산에 사용된다.
#
# 복수의 데이터를 한번에 보내어 한번에 연산을 할수 있고, 그 결과를 반환할 수 있다. 이런 방법으로 연산 시간을 줄일 수 있다.
#
# <br>
#
# 하지만, 복수의 데이터를 한번에 보내는 경우 한번에 보낸 결과가 한번에 오고 1번 업데이트 되면서 업데이트 되는 사항이 뭉개지는 단점이 있다.

# %%
def build_model():

  model = keras.Sequential()
  model.add(Dense(10, activation='tanh', input_shape=(1,)))
  model.add(Dense(10, activation='tanh'))
  model.add(Dense(1))

  model.compile(optimizer="SGD", loss="mse", metrics=["mse"])

  return model

def fit_with_batch_sizes(train_x, train_y, test_x, test_y, batch_sizes):

  for batch_size in batch_sizes:
    model = build_model()
    print("batch_size={}".format(batch_size))
    fit_one_more(model, train_x, train_y, test_x, test_y, batch_size)

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

# %% [markdown]
# ## batch_size 적용 : [1,2,5,10,20,50,100,200,500]

# %%
fit_with_batch_sizes(train_x, train_y, test_x, test_y, batch_sizes=[1,2,5,10,20,50,100,200,500])
# Out:
# batch_size=1
# elapsed : 100.3012764453888
# batch_size=2
# elapsed : 51.838141679763794
# batch_size=5
# elapsed : 22.21281623840332
# batch_size=10
# elapsed : 12.134780406951904
# batch_size=20
# elapsed : 7.339964866638184
# batch_size=50
# elapsed : 5.389750957489014
# batch_size=100
# elapsed : 3.670841932296753
# batch_size=200
# elapsed : 3.6978063583374023
# batch_size=500
# elapsed : 3.7025442123413086

# %% [markdown]
# 맨 앞의 결과가 batch_size 1인 경우이다. 100개의 데이터를 매번 1개 씩 보냈고, 매번 업데이트 했다.
#
# batch_size를 키우면, 시간은 줄어들지만 학습이 빠르게 진행되지 않는다.

# %% [markdown]
# # 학습 진행된 내역 보기

# %% [markdown]
# ## model.fit()의 반환값 history
#
# 반환된 history의 loss로 진행 상황을 확인.

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
# model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
history = model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))
# Out:
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_82 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_83 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_84 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 7.361281156539917

# %%
plt.plot(history.history['loss'])

# %% [markdown]
# ## model.fit() verbose
#
# - 0 : X
# - 1: progress bar
# - 2 : 1 line per epoch

# %%
# (train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.01)
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.0001)

model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()

print(train_x.shape)

start_time = time.time()
# history = model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
history = model.fit(train_x, train_y, epochs=5, verbose=1, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))
# Out:
# Model: "sequential_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_88 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_89 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_90 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# (60000,)
# Epoch 1/5
# 60000/60000 - 6s - loss: 0.2209 - mean_squared_error: 0.2209
# Epoch 2/5
# 60000/60000 - 5s - loss: 0.1077 - mean_squared_error: 0.1077
# Epoch 3/5
# 60000/60000 - 5s - loss: 0.0547 - mean_squared_error: 0.0547
# Epoch 4/5
# 60000/60000 - 5s - loss: 0.0192 - mean_squared_error: 0.0192
# Epoch 5/5
# 60000/60000 - 5s - loss: 0.0086 - mean_squared_error: 0.0086
# elapsed : 27.608429431915283

# %% [markdown]
# # 학습 시에 validation

# %% [markdown]
# ## model.fit()의 validation_data

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
# history = model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
history = model.fit(train_x, train_y, epochs=1000, verbose=1, batch_size=20, validation_data=(test_x, test_y))
print("elapsed : {}".format(time.time() - start_time))
# Out:
# Model: "sequential_28"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_91 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_92 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_93 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60 samples, validate on 40 samples
# Epoch 1/1000
# 60/60 [==============================] - 0s 7ms/sample - loss: 1.7064 - mean_squared_error: 1.7064 - val_loss: 0.4434 - val_mean_squared_error: 0.4434
# Epoch 2/1000
# 60/60 [==============================] - 0s 325us/sample - loss: 0.4610 - mean_squared_error: 0.4610 - val_loss: 0.4652 - val_mean_squared_error: 0.4652
# Epoch 3/1000
# 60/60 [==============================] - 0s 229us/sample - loss: 0.3946 - mean_squared_error: 0.3946 - val_loss: 0.4812 - val_mean_squared_error: 0.4812
ss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()

# %% [markdown]
# ## model.fit()의 validation_split
#
# 따로 validation 데이터를 주지 않고, test 데이터로 준 것의 일부를 validation에 사용.
#
# validation에 사용된 데이터는 학습에 사용되지 않는다.

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
# history = model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
history = model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20, validation_split=0.1)
print("elapsed : {}".format(time.time() - start_time))
# Out:
# Model: "sequential_29"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_94 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_95 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_96 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 10.968835353851318

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()

# %% [markdown]
# # 데이터 크기와 epoch 수

# %%
# (train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.01)
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.0001)

model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()

start_time = time.time()
# history = model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
history = model.fit(train_x, train_y, epochs=5, verbose=2, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))
# Out:
# Model: "sequential_30"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_97 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_98 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_99 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 60000/60000 - 6s - loss: 0.2517 - mean_squared_error: 0.2517
# Epoch 2/5
# 60000/60000 - 5s - loss: 0.1147 - mean_squared_error: 0.1147
# Epoch 3/5
# 60000/60000 - 5s - loss: 0.0781 - mean_squared_error: 0.0781
# Epoch 4/5
# 60000/60000 - 5s - loss: 0.0393 - mean_squared_error: 0.0393
# Epoch 5/5
# 60000/60000 - 5s - loss: 0.0125 - mean_squared_error: 0.0125
# elapsed : 28.071099996566772

# %%
y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()

# %% [markdown]
# train_x의 데이터 수가 6000개. epoch는 5. 총 30,000번 업데이트 되었다.
#
#
# epoch가 적어도 데이터 수가 많으면 학습 잘된다.

# %% [markdown]
# # model.fit()의 shuffle - 학습 시의 데이터 섞기
#
# 학습 시에 데이터를 섞어 주지 않으면 특정 데이터 순서로 학습이 일어나 편향이 생길 수있다.

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.01)

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()

start_time = time.time()
history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time)) 

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_31"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_100 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_101 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_102 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 3.699143648147583

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()

start_time = time.time()
# history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20)
history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20, shuffle=True)
print("elapsed : {}".format(time.time() - start_time)) 

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_32"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_103 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_104 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_105 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 3.7709591388702393

# %% [markdown]
# 학습된 결과가 살짝 향상된 것을 볼 수 있다.
#
# 편향을 방지하기 위해서라도 항상 shuffle하는 것이 좋다.

# %% [markdown]
# # 데이터 준비

# %% [markdown]
# ## Shuffle

# %%
x = np.arange(0,10,0.1)
# np.random.shuffle(x) # COMMENTED
y = np.sin(x)

split_index = int(x.shape[0]*0.6)
print(split_index)

train_x, test_x = x[:split_index], x[split_index:]
train_y, test_y = y[:split_index], y[split_index:]

plt.scatter(train_x, train_y)
plt.scatter(test_x, test_y, color="r")
# Out:
# 60

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()

start_time = time.time()
history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time)) 

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0816 10:27:17.681707 140412517930880 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                20
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 4.123774290084839

# %% [markdown]
# train 데이터와 test 데이터가 서로 떨어져 있다.
#
# train 영역의 데이터로 학습된 모델은 test 영역의 데이터에 적용하지 못한다.
#
# 전체데이터를 잘 섞어 주고, 이를 train, test로 나누어야 한다.

# %%
x = np.arange(0,10,0.1)
np.random.shuffle(x) # UNCOMMENT
y = np.sin(x)

split_index = int(x.shape[0]*0.6)
print(split_index)

train_x, test_x = x[:split_index], x[split_index:]
train_y, test_y = y[:split_index], y[split_index:]

plt.scatter(train_x, train_y)
plt.scatter(test_x, test_y, color="r")
# Out:
# 60

# %% [markdown]
# ## Normalization/Standardization
#
# 입력이 여러 차원일 때 각 차원의 입력을 동일한 스케일로 맞추어주면, 학습이 빠르게 진행된다고 한다.
#
# - Normalization : 전체 데이터를 0~1로 변환해준다.
# - Standardization : 평균을 0, 표준편차를 1이되도록 변환해 준다.

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=-10, end=10, step=0.1)

print("min=",np.min(train_x))
print("max=",np.max(train_x))

plt.scatter(train_x, train_y)
plt.scatter(test_x, test_y, color="r")
# Out:
# min= -9.600000000000001
# max= 9.899999999999928

# %%
min = -10 # ADDED
max = 10 # ADDED

train_x = (train_x-min)/(max-min) # ADDED
test_x = (test_x-min)/(max-min) # ADDED

print("min=",np.min(train_x))
print("max=",np.max(train_x))

plt.scatter(train_x, train_y)
plt.scatter(test_x, test_y, color="r")
# Out:
# min= 0.019999999999999928
# max= 0.9949999999999963

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_38"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_125 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_126 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_127 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 8.89617109298706
# 40/40 [==============================] - 0s 5ms/sample - loss: 0.0614 - mean_squared_error: 0.0614
# loss= 0.061400238424539566
# mse= 0.061400242

# %% [markdown]
# # 모델 저장과 로딩

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_35"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_112 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_113 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_114 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 8.070200681686401
# 40/40 [==============================] - 0s 3ms/sample - loss: 0.1501 - mean_squared_error: 0.1501
# loss= 0.15005545914173127
# mse= 0.15005545

# %%
model.save('my_model.h5')

# !ls -al

new_model = keras.models.load_model('my_model.h5')

y_ = new_model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# total 52
# drwxr-xr-x 1 root root  4096 Aug 14 12:47 .
# drwxr-xr-x 1 root root  4096 Aug 14 11:06 ..
# -rw-r--r-- 1 root root 12510 Aug 14 11:30 base_result.png
# drwxr-xr-x 1 root root  4096 Aug  7 16:05 .config
# -rw-r--r-- 1 root root 19760 Aug 14 12:47 my_model.h5
# drwxr-xr-x 1 root root  4096 Aug  2 16:06 sample_data
# W0814 12:47:46.716366 139865081911168 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0814 12:47:46.718369 139865081911168 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %% [markdown]
# ## TensorFlow 포멧의 저장과 로딩

# %%
keras.experimental.export_saved_model(model, 'model_path')

# !ls -al
# !ls -al model_path

new_model = keras.experimental.load_from_saved_model('model_path')


y_ = new_model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# W0813 04:27:43.873593 140167977838464 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/saved_model/signature_def_utils_impl.py:253: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# W0813 04:27:43.875437 140167977838464 export_utils.py:182] Export includes no default signature!
# W0813 04:27:44.476985 140167977838464 export_utils.py:182] Export includes no default signature!
# total 52
# drwxr-xr-x 1 root root  4096 Aug 13 04:27 .
# drwxr-xr-x 1 root root  4096 Aug 13 04:08 ..
# -rw-r--r-- 1 root root 12177 Aug 13 04:12 base_result.png
# drwxr-xr-x 1 root root  4096 Aug  7 16:05 .config
# drwxr-xr-x 4 root root  4096 Aug 13 04:27 model_path
# -rw-r--r-- 1 root root 19760 Aug 13 04:27 my_model.h5
# drwxr-xr-x 1 root root  4096 Aug  2 16:06 sample_data
# total 128
# drwxr-xr-x 4 root root   4096 Aug 13 04:27 .
# drwxr-xr-x 1 root root   4096 Aug 13 04:27 ..
# drwxr-xr-x 2 root root   4096 Aug 13 04:27 assets
# -rw-r--r-- 1 root root 113765 Aug 13 04:27 saved_model.pb
# drwxr-xr-x 2 root root   4096 Aug 13 04:27 variables

# %% [markdown]
# # GPU 사용
#
# 따로 명시하지 않아도 default로 GPU를 사용한다.
#
# 명시적으로 설정할 수도 있다.

# %% [markdown]
# ## 디바이스 리스트 보기

# %%
from tensorflow.python.client import device_lib
print(tf.test.gpu_device_name())
# Out:
# /device:GPU:0

# %% [markdown]
# ## 디바이스 설정
#
# 다음의 디바이스 이름이 가능
#
# - /device:GPU:0
# - /GPU:0
# - /gpu:0
# - /gpu
# - /cpu:0
# - /cpu

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.01)

# %%
with tf.device('/device:GPU:0'): # ADDED

  model = keras.Sequential()
  model.add(Dense(10, activation='tanh', input_shape=(1,)))
  model.add(Dense(10, activation='tanh'))
  model.add(Dense(1))


  model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
  model.summary()

  start_time = time.time()
  history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20)
  print("elapsed : {}".format(time.time() - start_time)) 

  y_ = model.predict(test_x)

  plt.scatter(test_x,test_y)
  plt.scatter(test_x,y_,color='r')
  plt.show()
# Out:
# Model: "sequential_40"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_131 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_132 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_133 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 4.7871012687683105

# %%
# with tf.device('/device:GPU:0'):
with tf.device('/GPU:0'):

  model = keras.Sequential()
  model.add(Dense(10, activation='tanh', input_shape=(1,)))
  model.add(Dense(10, activation='tanh'))
  model.add(Dense(1))


  model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
  model.summary()

  start_time = time.time()
  history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20)
  print("elapsed : {}".format(time.time() - start_time)) 

  y_ = model.predict(test_x)

  plt.scatter(test_x,test_y)
  plt.scatter(test_x,y_,color='r')
  plt.show()
# Out:
# Model: "sequential_41"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_134 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_135 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_136 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 4.9093663692474365

# %%
# with tf.device('/device:GPU:0'):
with tf.device('/gpu:0'):

  model = keras.Sequential()
  model.add(Dense(10, activation='tanh', input_shape=(1,)))
  model.add(Dense(10, activation='tanh'))
  model.add(Dense(1))


  model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
  model.summary()

  start_time = time.time()
  history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20)
  print("elapsed : {}".format(time.time() - start_time)) 

  y_ = model.predict(test_x)

  plt.scatter(test_x,test_y)
  plt.scatter(test_x,y_,color='r')
  plt.show()
# Out:
# Model: "sequential_42"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_137 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_138 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_139 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 4.902727365493774

# %%
# with tf.device('/GPU:0'):
with tf.device('/gpu:0'):

  model = keras.Sequential()
  model.add(Dense(10, activation='tanh', input_shape=(1,)))
  model.add(Dense(10, activation='tanh'))
  model.add(Dense(1))


  model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
  model.summary()

  start_time = time.time()
  history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20)
  print("elapsed : {}".format(time.time() - start_time)) 

  y_ = model.predict(test_x)

  plt.scatter(test_x,test_y)
  plt.scatter(test_x,y_,color='r')
  plt.show()
# Out:
# Model: "sequential_43"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_140 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_141 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_142 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 4.909321546554565

# %%
# with tf.device('/GPU:0'):
with tf.device('/gpu'):

  model = keras.Sequential()
  model.add(Dense(10, activation='tanh', input_shape=(1,)))
  model.add(Dense(10, activation='tanh'))
  model.add(Dense(1))


  model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
  model.summary()

  start_time = time.time()
  history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20)
  print("elapsed : {}".format(time.time() - start_time)) 

  y_ = model.predict(test_x)

  plt.scatter(test_x,test_y)
  plt.scatter(test_x,y_,color='r')
  plt.show()
# Out:
# Model: "sequential_44"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_143 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_144 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_145 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 4.9103076457977295

# %%
# with tf.device('/GPU:0'):
with tf.device('/CPU:0'):

  model = keras.Sequential()
  model.add(Dense(10, activation='tanh', input_shape=(1,)))
  model.add(Dense(10, activation='tanh'))
  model.add(Dense(1))


  model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
  model.summary()

  start_time = time.time()
  history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20)
  print("elapsed : {}".format(time.time() - start_time)) 

  y_ = model.predict(test_x)

  plt.scatter(test_x,test_y)
  plt.scatter(test_x,y_,color='r')
  plt.show()
# Out:
# Model: "sequential_45"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_146 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_147 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_148 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 3.5686676502227783

# %%
# with tf.device('/GPU:0'):
with tf.device('/CPU'):

  model = keras.Sequential()
  model.add(Dense(10, activation='tanh', input_shape=(1,)))
  model.add(Dense(10, activation='tanh'))
  model.add(Dense(1))


  model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
  model.summary()

  start_time = time.time()
  history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20)
  print("elapsed : {}".format(time.time() - start_time)) 

  y_ = model.predict(test_x)

  plt.scatter(test_x,test_y)
  plt.scatter(test_x,y_,color='r')
  plt.show()
# Out:
# Model: "sequential_46"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_149 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_150 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_151 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 3.5223915576934814

# %% [markdown]
# # Overfitting 처리
#
# - DropOut
# - BatchNormalization
# - Regularization

# %% [markdown]
# ## DropOut 레이어

# %%
from tensorflow.keras.layers import Dropout

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dropout(0.1)) # ADDED
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_47"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_152 (Dense)            (None, 10)                20
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense_153 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_154 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 10.028263807296753
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.1967 - mean_squared_error: 0.1967
# loss= 0.19667569696903228
# mse= 0.19667569

# %% [markdown]
# ## BatchNormalization 레이어

# %%
from tensorflow.keras.layers import BatchNormalization

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(BatchNormalization()) # ADDED
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_48"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_155 (Dense)            (None, 10)                20
# _________________________________________________________________
# batch_normalization (BatchNo (None, 10)                40
# _________________________________________________________________
# dense_156 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_157 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 181
# Trainable params: 161
# Non-trainable params: 20
# _________________________________________________________________
# elapsed : 12.237880945205688
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.0931 - mean_squared_error: 0.0931
# loss= 0.09305349886417388
# mse= 0.0930535

# %% [markdown]
# ## Regularization
#
# Dense() 생성시에 kernel_regularization, bias_regularization으로 설정한다.
#
# - l1()
# - l1_l2()
# - l2()

# %%
from tensorflow.keras.regularizers import l1, l2

(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

model = keras.Sequential()
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
# model.add(Dense(10, activation='tanh'))
model.add(Dense(10, activation='tanh', input_shape=(1,), kernel_regularizer=l2(0.001)))
model.add(Dense(10, activation='tanh', kernel_regularizer=l2(0.001)))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_49"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_158 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_159 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_160 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# W0813 04:29:00.962242 140167977838464 util.py:244] Unresolved object in checkpoint: (root).optimizer.decay
# W0813 04:29:00.964253 140167977838464 util.py:244] Unresolved object in checkpoint: (root).optimizer.learning_rate
# W0813 04:29:00.965291 140167977838464 util.py:244] Unresolved object in checkpoint: (root).optimizer.momentum
# W0813 04:29:00.971273 140167977838464 util.py:252] A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# W0813 04:29:00.977120 140167977838464 util.py:244] Unresolved object in checkpoint: (root).optimizer
# W0813 04:29:00.979098 140167977838464 util.py:244] Unresolved object in checkpoint: (root).optimizer.iter
# W0813 04:29:00.981695 140167977838464 util.py:244] Unresolved object in checkpoint: (root).optimizer.decay
# W0813 04:29:00.983344 140167977838464 util.py:244] Unresolved object in checkpoint: (root).optimizer.learning_rate
# W0813 04:29:00.984951 140167977838464 util.py:244] Unresolved object in checkpoint: (root).optimizer.momentum
# W0813 04:29:00.986894 140167977838464 util.py:252] A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# elapsed : 10.796214580535889
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.1749 - mean_squared_error: 0.1590
# loss= 0.17491161227226257
# mse= 0.15898657

# %% [markdown]
# # 웨이트 초기값
#
# Dense() 생성시에 kernel_initializer, bias_initializer로 설정한다.
#
# - 'he_normal'
# - 'lecun_normal'

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

model = keras.Sequential()
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
# model.add(Dense(10, activation='tanh'))
model.add(Dense(10, activation='tanh', input_shape=(1,), kernel_initializer='he_normal'))
model.add(Dense(10, activation='tanh', kernel_initializer='he_normal'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_50"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_161 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_162 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_163 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 9.871533632278442
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.1827 - mean_squared_error: 0.1827
# loss= 0.18268578350543976
# mse= 0.18268578

# %% [markdown]
# # 노이즈

# %%
def train_sin_with_noise(noise_size):

  # x = np.arange(0,10,0.1)
  x = np.arange(0,10,0.001)
  np.random.shuffle(x)
  y = np.sin(x)

  noiseless_y = np.copy(y) # ADD
  y = y + np.random.rand(y.shape[0])*noise_size - noise_size/2.0 # ADD

  split_index = int(x.shape[0]*0.6)

  train_x, test_x = x[:split_index], x[split_index:]
  train_y, test_y = y[:split_index], y[split_index:]
  test_noiseless_y = noiseless_y[split_index:] # ADD

  model = keras.Sequential()
  model.add(Dense(10, activation='tanh', input_shape=(1,)))
  model.add(Dense(10, activation='tanh'))
  model.add(Dense(1))


  model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
  model.summary()


  start_time = time.time()
  # model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
  model.fit(train_x, train_y, epochs=100, verbose=1, batch_size=20)
  print("elapsed : {}".format(time.time() - start_time))    


  loss, mse = model.evaluate(test_x, test_y)
  print("loss=",loss)
  print("mse=",mse)


  y_ = model.predict(test_x)

  # plt.scatter(test_x,test_y)
  plt.scatter(test_x,test_noiseless_y)
  plt.scatter(test_x,y_,color='r')
  plt.show()

# %% [markdown]
# ## 노이즈 없을 때

# %%
train_sin_with_noise(0.0)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_30 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_31 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_32 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 6000/6000 [==============================] - 1s 162us/sample - loss: 0.4342 - mean_squared_error: 0.4342
# Epoch 2/100
# 6000/6000 [==============================] - 1s 156us/sample - loss: 0.3800 - mean_squared_error: 0.3800
# Epoch 3/100
# 6000/6000 [==============================] - 1s 145us/sample - loss: 0.3642 - mean_squared_error: 0.3642
# Epoch 4/100
# 6000/6000 [==============================] - 1s 141us/sample - loss: 0.3463 - mean_squared_error: 0.3463
# Epoch 5/100
# 6000/6000 [==============================] - 1s 145us/sample - loss: 0.3203 - mean_squared_error: 0.3203
# Epoch 6/100
# 6000/6000 [==============================] - 1s 136us/sample - loss: 0.2928 - mean_squared_error: 0.2928
# 6000/6000 [==============================] - 1s 144us/sample - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 87/100
# 6000/6000 [==============================] - 1s 141us/sample - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 88/100
# 6000/6000 [==============================] - 1s 149us/sample - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 89/100
# 6000/6000 [==============================] - 1s 159us/sample - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 90/100
# 6000/6000 [==============================] - 1s 152us/sample - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 91/100
# 6000/6000 [==============================] - 1s 157us/sample - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 92/100
# 6000/6000 [==============================] - 1s 151us/sample - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 93/100
# 6000/6000 [==============================] - 1s 143us/sample - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 94/100
# 6000/6000 [==============================] - 1s 145us/sample - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 95/100
# 6000/6000 [==============================] - 1s 149us/sample - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 96/100
# 6000/6000 [==============================] - 1s 157us/sample - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 97/100
# 6000/6000 [==============================] - 1s 157us/sample - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 98/100
# 6000/6000 [==============================] - 1s 154us/sample - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 99/100
# 6000/6000 [==============================] - 1s 141us/sample - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 100/100
# 6000/6000 [==============================] - 1s 149us/sample - loss: 0.0023 - mean_squared_error: 0.0023
# elapsed : 90.50122952461243
# 4000/4000 [==============================] - 0s 66us/sample - loss: 3.3874e-04 - mean_squared_error: 3.3874e-04
# loss= 0.00033874278777511793
# mse= 0.0003387428

# %% [markdown]
# ## 노이즈 크기 0.1

# %%
train_sin_with_noise(0.1)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_33 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_34 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_35 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 6000/6000 [==============================] - 1s 181us/sample - loss: 0.4082 - mean_squared_error: 0.4082
# Epoch 2/100
# 6000/6000 [==============================] - 1s 175us/sample - loss: 0.3697 - mean_squared_error: 0.3697
# Epoch 3/100
# 6000/6000 [==============================] - 1s 158us/sample - loss: 0.3427 - mean_squared_error: 0.3427
# Epoch 4/100
# 6000/6000 [==============================] - 1s 151us/sample - loss: 0.3167 - mean_squared_error: 0.3167
# Epoch 5/100
# 6000/6000 [==============================] - 1s 144us/sample - loss: 0.2864 - mean_squared_error: 0.2864
# Epoch 6/100
# 6000/6000 [==============================] - 1s 146us/sample - loss: 0.2665 - mean_squared_error: 0.2665
# Epoch 7/100
# 6000/6000 [==============================] - 1s 152us/sample - loss: 0.2415 - mean_squared_error: 0.2415
# Epoch 8/100
# 6000/6000 [==============================] - 1s 137us/sample - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 88/100
# 6000/6000 [==============================] - 1s 157us/sample - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 89/100
# 6000/6000 [==============================] - 1s 147us/sample - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 90/100
# 6000/6000 [==============================] - 1s 143us/sample - loss: 0.0050 - mean_squared_error: 0.0050
# Epoch 91/100
# 6000/6000 [==============================] - 1s 138us/sample - loss: 0.0031 - mean_squared_error: 0.0031
# Epoch 92/100
# 6000/6000 [==============================] - 1s 157us/sample - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 93/100
# 6000/6000 [==============================] - 1s 160us/sample - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 94/100
# 6000/6000 [==============================] - 1s 155us/sample - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 95/100
# 6000/6000 [==============================] - 1s 158us/sample - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 96/100
# 6000/6000 [==============================] - 1s 141us/sample - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 97/100
# 6000/6000 [==============================] - 1s 158us/sample - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 98/100
# 6000/6000 [==============================] - 1s 157us/sample - loss: 0.0074 - mean_squared_error: 0.0074
# Epoch 99/100
# 6000/6000 [==============================] - 1s 153us/sample - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 100/100
# 6000/6000 [==============================] - 1s 136us/sample - loss: 0.0021 - mean_squared_error: 0.0021
# elapsed : 90.811208486557
# 4000/4000 [==============================] - 0s 71us/sample - loss: 0.0121 - mean_squared_error: 0.0121
# loss= 0.012141823215410113
# mse= 0.012141823

# %% [markdown]
# ## 노이즈 크기 0.5

# %%
train_sin_with_noise(0.5)
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_36 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_37 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_38 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 6000/6000 [==============================] - 1s 157us/sample - loss: 0.4195 - mean_squared_error: 0.4195
# Epoch 2/100
# 6000/6000 [==============================] - 1s 145us/sample - loss: 0.3707 - mean_squared_error: 0.3707
# Epoch 3/100
# 6000/6000 [==============================] - 1s 149us/sample - loss: 0.3419 - mean_squared_error: 0.3419
# Epoch 4/100
# 6000/6000 [==============================] - 1s 160us/sample - loss: 0.3082 - mean_squared_error: 0.3082
# Epoch 5/100
# 6000/6000 [==============================] - 1s 154us/sample - loss: 0.2724 - mean_squared_error: 0.2724
# Epoch 6/100
# 6000/6000 [==============================] - 1s 142us/sample - loss: 0.2532 - mean_squared_error: 0.2532
# Epoch 7/100
# 6000/6000 [==============================] - 1s 143us/sample - loss: 0.2261 - mean_squared_error: 0.2261
# Epoch 8/100
# 6000/6000 [==============================] - 1s 138us/sample - loss: 0.2044 - mean_squared_error: 0.2044
# Epoch 9/100
# 6000/6000 [==============================] - 1s 147us/sample - loss: 0.0281 - mean_squared_error: 0.0281
# Epoch 89/100
# 6000/6000 [==============================] - 1s 143us/sample - loss: 0.0268 - mean_squared_error: 0.0268
# Epoch 90/100
# 6000/6000 [==============================] - 1s 143us/sample - loss: 0.0255 - mean_squared_error: 0.0255
# Epoch 91/100
# 6000/6000 [==============================] - 1s 136us/sample - loss: 0.0260 - mean_squared_error: 0.0260
# Epoch 92/100
# 6000/6000 [==============================] - 1s 153us/sample - loss: 0.0266 - mean_squared_error: 0.0266
# Epoch 93/100
# 6000/6000 [==============================] - 1s 139us/sample - loss: 0.0259 - mean_squared_error: 0.0259
# Epoch 94/100
# 6000/6000 [==============================] - 1s 151us/sample - loss: 0.0268 - mean_squared_error: 0.0268
# Epoch 95/100
# 6000/6000 [==============================] - 1s 139us/sample - loss: 0.0270 - mean_squared_error: 0.0270
# Epoch 96/100
# 6000/6000 [==============================] - 1s 138us/sample - loss: 0.0270 - mean_squared_error: 0.0270
# Epoch 97/100
# 6000/6000 [==============================] - 1s 151us/sample - loss: 0.0259 - mean_squared_error: 0.0259
# Epoch 98/100
# 6000/6000 [==============================] - 1s 145us/sample - loss: 0.0244 - mean_squared_error: 0.0244
# Epoch 99/100
# 6000/6000 [==============================] - 1s 152us/sample - loss: 0.0268 - mean_squared_error: 0.0268
# Epoch 100/100
# 6000/6000 [==============================] - 1s 161us/sample - loss: 0.0249 - mean_squared_error: 0.0249
# elapsed : 89.95564150810242
# 4000/4000 [==============================] - 0s 61us/sample - loss: 0.0233 - mean_squared_error: 0.0233
# loss= 0.023321767419576644
# mse= 0.023321768

# %% [markdown]
# ## 노이즈 크기 1.0

# %%
train_sin_with_noise(1.0)
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_39 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_40 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_41 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 6000/6000 [==============================] - 1s 161us/sample - loss: 0.5027 - mean_squared_error: 0.5027
# Epoch 2/100
# 6000/6000 [==============================] - 1s 148us/sample - loss: 0.4633 - mean_squared_error: 0.4633
# Epoch 3/100
# 6000/6000 [==============================] - 1s 151us/sample - loss: 0.4400 - mean_squared_error: 0.4400
# Epoch 4/100
# 6000/6000 [==============================] - 1s 158us/sample - loss: 0.4153 - mean_squared_error: 0.4153
# Epoch 5/100
# 6000/6000 [==============================] - 1s 133us/sample - loss: 0.3857 - mean_squared_error: 0.3857
# Epoch 6/100
# 6000/6000 [==============================] - 1s 159us/sample - loss: 0.3528 - mean_squared_error: 0.3528
# Epoch 7/100
# 6000/6000 [==============================] - 1s 148us/sample - loss: 0.3224 - mean_squared_error: 0.3224
# Epoch 8/100
# 6000/6000 [==============================] - 1s 142us/sample - loss: 0.3048 - mean_squared_error: 0.3048
# Epoch 9/100
# 6000/6000 [==============================] - 1s 167us/sample - loss: 0.2863 - mean_squared_error: 0.2863
# Epoch 10/100
# Epoch 90/100
# 6000/6000 [==============================] - 1s 164us/sample - loss: 0.0979 - mean_squared_error: 0.0979
# Epoch 91/100
# 6000/6000 [==============================] - 1s 172us/sample - loss: 0.0949 - mean_squared_error: 0.0949
# Epoch 92/100
# 6000/6000 [==============================] - 1s 155us/sample - loss: 0.0944 - mean_squared_error: 0.0944
# Epoch 93/100
# 6000/6000 [==============================] - 1s 166us/sample - loss: 0.0928 - mean_squared_error: 0.0928
# Epoch 94/100
# 6000/6000 [==============================] - 1s 150us/sample - loss: 0.0944 - mean_squared_error: 0.0944
# Epoch 95/100
# 6000/6000 [==============================] - 1s 156us/sample - loss: 0.0917 - mean_squared_error: 0.0917
# Epoch 96/100
# 6000/6000 [==============================] - 1s 151us/sample - loss: 0.0948 - mean_squared_error: 0.0948
# Epoch 97/100
# 6000/6000 [==============================] - 1s 155us/sample - loss: 0.0954 - mean_squared_error: 0.0954
# Epoch 98/100
# 6000/6000 [==============================] - 1s 157us/sample - loss: 0.0933 - mean_squared_error: 0.0933
# Epoch 99/100
# 6000/6000 [==============================] - 1s 158us/sample - loss: 0.0926 - mean_squared_error: 0.0926
# Epoch 100/100
# 6000/6000 [==============================] - 1s 150us/sample - loss: 0.0944 - mean_squared_error: 0.0944
# elapsed : 91.60636639595032
# 4000/4000 [==============================] - 0s 66us/sample - loss: 0.0869 - mean_squared_error: 0.0869
# loss= 0.08689910796284675
# mse= 0.086899064

# %% [markdown]
# ## 노이즈 크기 10.0

# %%
train_sin_with_noise(10.0)
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_42 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_43 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_44 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 6000/6000 [==============================] - 1s 147us/sample - loss: 8.6708 - mean_squared_error: 8.6707
# Epoch 2/100
# 6000/6000 [==============================] - 1s 149us/sample - loss: 8.6052 - mean_squared_error: 8.6052
# Epoch 3/100
# 6000/6000 [==============================] - 1s 140us/sample - loss: 8.5985 - mean_squared_error: 8.5985
# Epoch 4/100
# 6000/6000 [==============================] - 1s 149us/sample - loss: 8.5854 - mean_squared_error: 8.5854
# Epoch 5/100
# 6000/6000 [==============================] - 1s 144us/sample - loss: 8.5874 - mean_squared_error: 8.5874
# Epoch 6/100
# 6000/6000 [==============================] - 1s 150us/sample - loss: 8.5672 - mean_squared_error: 8.5672
# Epoch 7/100
# 6000/6000 [==============================] - 1s 159us/sample - loss: 8.5664 - mean_squared_error: 8.5664
# Epoch 8/100
# 6000/6000 [==============================] - 1s 135us/sample - loss: 8.5492 - mean_squared_error: 8.5492
# Epoch 9/100
# 6000/6000 [==============================] - 1s 149us/sample - loss: 8.5343 - mean_squared_error: 8.5343
# Epoch 10/100
# 6000/6000 [==============================] - 1s 137us/sample - loss: 8.5268 - mean_squared_error: 8.5268
# Epoch 11/100
# 6000/6000 [==============================] - 1s 149us/sample - loss: 8.5126 - mean_squared_error: 8.5126
# Epoch 91/100
# 6000/6000 [==============================] - 1s 150us/sample - loss: 8.2984 - mean_squared_error: 8.2984
# Epoch 92/100
# 6000/6000 [==============================] - 1s 149us/sample - loss: 8.3123 - mean_squared_error: 8.3123
# Epoch 93/100
# 6000/6000 [==============================] - 1s 145us/sample - loss: 8.3062 - mean_squared_error: 8.3062
# Epoch 94/100
# 6000/6000 [==============================] - 1s 145us/sample - loss: 8.3142 - mean_squared_error: 8.3142
# Epoch 95/100
# 6000/6000 [==============================] - 1s 153us/sample - loss: 8.3116 - mean_squared_error: 8.3116
# Epoch 96/100
# 6000/6000 [==============================] - 1s 170us/sample - loss: 8.3072 - mean_squared_error: 8.3072
# Epoch 97/100
# 6000/6000 [==============================] - 1s 149us/sample - loss: 8.3225 - mean_squared_error: 8.3225
# Epoch 98/100
# 6000/6000 [==============================] - 1s 159us/sample - loss: 8.3141 - mean_squared_error: 8.3141
# Epoch 99/100
# 6000/6000 [==============================] - 1s 162us/sample - loss: 8.2976 - mean_squared_error: 8.2976
# Epoch 100/100
# 6000/6000 [==============================] - 1s 155us/sample - loss: 8.2956 - mean_squared_error: 8.2956
# elapsed : 90.12801957130432
# 4000/4000 [==============================] - 0s 71us/sample - loss: 8.2277 - mean_squared_error: 8.2277
# loss= 8.227736564636231
# mse= 8.227736

# %% [markdown]
# ## 노이즈 피쳐
# 노이즈 입력을 하나 더 준다.

# %%
x = np.arange(0,10,1.0)
np.random.shuffle(x)

y = np.zeros((x.shape[0],2))
y[:,0] = np.sin(x)
y[:,1] = np.random.rand(x.shape[0])
# Out:
# (10, 2)
# [[ 0.          0.54118037]
#  [ 0.84147098  0.84845114]
#  [ 0.90929743  0.35767759]
#  [ 0.14112001  0.05478037]
#  [-0.7568025   0.12516062]
#  [-0.95892427  0.70578877]
#  [-0.2794155   0.68956759]
#  [ 0.6569866   0.24470211]
#  [ 0.98935825  0.43824702]
#  [ 0.41211849  0.49409436]]

# %%
# x = np.arange(0,10,0.001)
x = np.zeros((10000,2))
x[:,0] = np.arange(0,10,0.001) # ADD
x[:,1] = np.random.rand(x.shape[0]) # ADD
np.random.shuffle(x)

# y = np.sin(x)
y = np.sin(x[:,0])

split_index = int(x.shape[0]*0.6)

train_x, test_x = x[:split_index], x[split_index:]
train_y, test_y = y[:split_index], y[split_index:]

model = keras.Sequential()
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh', input_shape=(2,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()


start_time = time.time()
# model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
model.fit(train_x, train_y, epochs=100, verbose=1, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mse = model.evaluate(test_x, test_y)
print("loss=",loss)
print("mse=",mse)


y_ = model.predict(test_x)

plt.scatter(test_x[:,0],test_y)
plt.scatter(test_x[:,0],y_,color='r')
plt.show()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_54 (Dense)             (None, 10)                30
# _________________________________________________________________
# dense_55 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_56 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 6000/6000 [==============================] - 1s 175us/sample - loss: 0.3844 - mean_squared_error: 0.3844
# Epoch 2/100
# 6000/6000 [==============================] - 1s 159us/sample - loss: 0.3336 - mean_squared_error: 0.3336
# Epoch 3/100
# 6000/6000 [==============================] - 1s 157us/sample - loss: 0.3039 - mean_squared_error: 0.3039
# Epoch 4/100
# 6000/6000 [==============================] - 1s 168us/sample - loss: 0.2777 - mean_squared_error: 0.2777
# Epoch 5/100
# 6000/6000 [==============================] - 1s 150us/sample - loss: 0.2513 - mean_squared_error: 0.2513
# Epoch 6/100
# 6000/6000 [==============================] - 1s 150us/sample - loss: 0.2280 - mean_squared_error: 0.2280
# Epoch 7/100
# 6000/6000 [==============================] - 1s 151us/sample - loss: 0.2137 - mean_squared_error: 0.2137
# Epoch 8/100
# 6000/6000 [==============================] - 1s 150us/sample - loss: 0.1975 - mean_squared_error: 0.1975
# Epoch 9/100
# 6000/6000 [==============================] - 1s 143us/sample - loss: 0.1916 - mean_squared_error: 0.1916
# Epoch 10/100
# 6000/6000 [==============================] - 1s 150us/sample - loss: 0.1831 - mean_squared_error: 0.1831
# Epoch 11/100
# 6000/6000 [==============================] - 1s 146us/sample - loss: 0.1762 - mean_squared_error: 0.1762
# Epoch 12/100
# 6000/6000 [==============================] - 1s 143us/sample - loss: 0.1685 - mean_squared_error: 0.1685
# Epoch 13/100
# 6000/6000 [==============================] - 1s 153us/sample - loss: 0.1649 - mean_squared_error: 0.1649
# Epoch 14/100
# 6000/6000 [==============================] - 1s 154us/sample - loss: 0.1567 - mean_squared_error: 0.1567
# Epoch 15/100
# 6000/6000 [==============================] - 1s 143us/sample - loss: 0.1521 - mean_squared_error: 0.1521
# Epoch 16/100
# 6000/6000 [==============================] - 1s 146us/sample - loss: 0.1471 - mean_squared_error: 0.1471
# Epoch 17/100
# 6000/6000 [==============================] - 1s 162us/sample - loss: 0.1419 - mean_squared_error: 0.1419
# Epoch 18/100
# 6000/6000 [==============================] - 1s 159us/sample - loss: 0.1345 - mean_squared_error: 0.1345
# Epoch 19/100
# 6000/6000 [==============================] - 1s 151us/sample - loss: 0.1320 - mean_squared_error: 0.1320
# Epoch 20/100
# 6000/6000 [==============================] - 1s 158us/sample - loss: 0.1291 - mean_squared_error: 0.1291
# Epoch 21/100
# 6000/6000 [==============================] - 1s 159us/sample - loss: 0.1271 - mean_squared_error: 0.1271
# Epoch 22/100
# 6000/6000 [==============================] - 1s 150us/sample - loss: 0.1254 - mean_squared_error: 0.1254
# Epoch 23/100
# 6000/6000 [==============================] - 1s 161us/sample - loss: 0.1217 - mean_squared_error: 0.1217
# Epoch 24/100
# 6000/6000 [==============================] - 1s 143us/sample - loss: 0.1210 - mean_squared_error: 0.1210
# Epoch 25/100
# 6000/6000 [==============================] - 1s 162us/sample - loss: 0.1175 - mean_squared_error: 0.1175
# 6000/6000 [==============================] - 1s 134us/sample - loss: 0.0235 - mean_squared_error: 0.0235
# Epoch 79/100
# 6000/6000 [==============================] - 1s 136us/sample - loss: 0.0225 - mean_squared_error: 0.0225
# Epoch 80/100
# 6000/6000 [==============================] - 1s 162us/sample - loss: 0.0182 - mean_squared_error: 0.0182
# Epoch 81/100
# 6000/6000 [==============================] - 1s 150us/sample - loss: 0.0205 - mean_squared_error: 0.0205
# Epoch 82/100
# 6000/6000 [==============================] - 1s 156us/sample - loss: 0.0195 - mean_squared_error: 0.0195
# Epoch 83/100
# 6000/6000 [==============================] - 1s 156us/sample - loss: 0.0185 - mean_squared_error: 0.0185
# Epoch 84/100
# 6000/6000 [==============================] - 1s 149us/sample - loss: 0.0138 - mean_squared_error: 0.0138
# Epoch 85/100
# 6000/6000 [==============================] - 1s 145us/sample - loss: 0.0128 - mean_squared_error: 0.0128
# Epoch 86/100
# 6000/6000 [==============================] - 1s 145us/sample - loss: 0.0148 - mean_squared_error: 0.0148
# Epoch 87/100
# 6000/6000 [==============================] - 1s 158us/sample - loss: 0.0129 - mean_squared_error: 0.0129
# Epoch 88/100
# 6000/6000 [==============================] - 1s 164us/sample - loss: 0.0102 - mean_squared_error: 0.0102
# Epoch 89/100
# 6000/6000 [==============================] - 1s 146us/sample - loss: 0.0100 - mean_squared_error: 0.0100
# Epoch 90/100
# 6000/6000 [==============================] - 1s 147us/sample - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 91/100
# 6000/6000 [==============================] - 1s 166us/sample - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 92/100
# 6000/6000 [==============================] - 1s 142us/sample - loss: 0.0079 - mean_squared_error: 0.0079
# Epoch 93/100
# 6000/6000 [==============================] - 1s 165us/sample - loss: 0.0101 - mean_squared_error: 0.0101
# Epoch 94/100
# 6000/6000 [==============================] - 1s 165us/sample - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 95/100
# 6000/6000 [==============================] - 1s 159us/sample - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 96/100
# 6000/6000 [==============================] - 1s 146us/sample - loss: 0.0069 - mean_squared_error: 0.0069
# Epoch 97/100
# 6000/6000 [==============================] - 1s 152us/sample - loss: 0.0069 - mean_squared_error: 0.0069
# Epoch 98/100
# 6000/6000 [==============================] - 1s 173us/sample - loss: 0.0079 - mean_squared_error: 0.0079
# Epoch 99/100
# 6000/6000 [==============================] - 1s 147us/sample - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 100/100
# 6000/6000 [==============================] - 1s 163us/sample - loss: 0.0061 - mean_squared_error: 0.0061
# elapsed : 92.26813864707947
# 4000/4000 [==============================] - 0s 68us/sample - loss: 0.0020 - mean_squared_error: 0.0020
# loss= 0.0019925347776152194
# mse= 0.001992535

# %% [markdown]
# # 학습 되지 않는 랜덤 함수
#
# 랜덤 한수의 경우 x와 y의 간에 관계가 없다.
#
# 입출력 간에 관계가 없는 함수로 학습되지 않는다.

# %%
x = np.arange(0,10,0.1)
np.random.shuffle(x)
# y = np.sin(x)
y = np.random.random_sample(x.shape[0])

split_index = int(x.shape[0]*0.6)
print(split_index)

train_x, test_x = x[:split_index], x[split_index:]
train_y, test_y = y[:split_index], y[split_index:]


plt.scatter(train_x, train_y)
plt.scatter(test_x, test_y, color="r")
# Out:
# 60

# %% [markdown]
# # Quiz - 2개의 입력, 1개의 출력
#
# x1 + x2 -> y의 함수를 학습
#
# x1과 x2는 0~10의 범위를 갖는다.

# %%
x1 = np.arange(0, 10, 0.1)
np.random.shuffle(x1)
x2 = np.arange(0, 10, 0.1)
np.random.shuffle(x2)

x = np.ones((x1.shape[0],2))
x[:,0] = x1
x[:,1] = x2
np.random.shuffle(x)

y = np.sum(x, axis=1)


s = int(x.shape[0]*0.6)
train_x, test_x = x[:s], x[s:]
train_y, test_y = y[:s], y[s:]



from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense

model = keras.Sequential()
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh', input_shape=(2,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))

model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()

start = time.time()
model.fit(train_x, train_y, epochs=1000*5, verbose=0, batch_size=20)
print("elapsed :", (time.time() - start))

loss, mse = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mse=", mse)
              
y_ = model.predict(test_x)

# plt.scatter(test_x,test_y)
# plt.scatter(test_x,y_, color="r")
plt.scatter(test_x.T[0],test_y)
plt.scatter(test_x.T[0],y_, color="r")
plt.show()
# Out:
# Model: "sequential_36"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_115 (Dense)            (None, 10)                30
# _________________________________________________________________
# dense_116 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_117 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 35.705761194229126
# 40/40 [==============================] - 0s 2ms/sample - loss: 0.0065 - mean_squared_error: 0.0065
# loss= 0.006477165594696998
# mse= 0.006477165

# %%
print(x.shape)
print(x[:5])
print(y[:5])
# Out:
# (100, 2)
# [[1.5 8.4]
#  [8.6 5.6]
#  [4.7 9.6]
#  [4.9 2.7]
#  [7.5 7.1]]
# [ 9.9 14.2 14.3  7.6 14.6]

# %% [markdown]
# # Quiz - 1개의 입력, 2개의 출력
#
# 다음과 같이 y는 2개의 값을 갖고, y1 = x%2, y2=x%3인 함수를 학습
#
# ```
# x = np.arange(0,10,0.1)
# y1 = x%2
# y2 = x%3
# ```

# %%
x = np.arange(0, 10, 0.1)
np.random.shuffle(x)
y1 = x%2
y2 = x%3

y = np.zeros((y.shape[0],2))
y[:,0] = y1
y[:,1] = y2


s = int(x.shape[0]*0.6)
train_x, test_x = x[:s], x[s:]
train_y, test_y = y[:s], y[s:]


from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense

model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
# model.add(Dense(1))
model.add(Dense(2))

model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()

start = time.time()
model.fit(train_x, train_y, epochs=1000*10, verbose=0, batch_size=20)
print("elapsed :", (time.time() - start))

loss, mse = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mse=", mse)
              
y_ = model.predict(test_x)

# plt.scatter(test_x,test_y)
# plt.scatter(test_x,y_, color="r")
plt.scatter(test_x,test_y[:,0])
plt.scatter(test_x,y_[:,0], color="r")
plt.show()

plt.scatter(test_x,test_y[:,1])
plt.scatter(test_x,y_[:,1], color="r")
plt.show()
# Out:
# Model: "sequential_52"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_167 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_168 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_169 (Dense)            (None, 2)                 22
# =================================================================
# Total params: 152
# Trainable params: 152
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 79.75155305862427
# 40/40 [==============================] - 0s 7ms/sample - loss: 0.4017 - mean_squared_error: 0.4017
# loss= 0.4017043113708496
# mse= 0.4017043

# %% [markdown]
# # Quiz - 2개의 입력, 2개의 출력
#
# x1 + x2 -> z,
#
# y1 = z%2, y2=z%3인 함수를 학습
#
# x1과 x2는 0~10의 범위를 갖는다.

# %%
x1 = np.arange(0, 10, 0.1)
np.random.shuffle(x1)
x2 = np.arange(0, 10, 0.1)
np.random.shuffle(x2)

x = np.ones((x1.shape[0],2))
x[:,0] = x1
x[:,1] = x2

z = x1 + x2
y1 = z%2
y2 = z%3

y = np.zeros((y.shape[0],2))
y[:,0] = y1
y[:,1] = y2


s = int(x.shape[0]*0.6)
train_x, test_x = x[:s], x[s:]
train_y, test_y = y[:s], y[s:]


from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense

model = keras.Sequential()
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh', input_shape=(2,)))
model.add(Dense(10, activation='tanh'))
# model.add(Dense(1))
model.add(Dense(2))

model.compile(optimizer="SGD", loss="mse", metrics=["mse"])
model.summary()

start = time.time()
model.fit(train_x, train_y, epochs=1000*10, verbose=0, batch_size=20)
print("elapsed :", (time.time() - start))

loss, mse = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mse=", mse)
              
y_ = model.predict(test_x)

# plt.scatter(test_x,test_y)
# plt.scatter(test_x,y_, color="r")
plt.scatter(test_x.T[0],test_y[:,0])
plt.scatter(test_x.T[0],y_[:,0], color="r")
plt.show()

plt.scatter(test_x.T[1],test_y[:,1])
plt.scatter(test_x.T[1],y_[:,1], color="r")
plt.show()
# Out:
# Model: "sequential_55"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_176 (Dense)            (None, 10)                30
# _________________________________________________________________
# dense_177 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_178 (Dense)            (None, 2)                 22
# =================================================================
# Total params: 162
# Trainable params: 162
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 80.7371563911438
# 40/40 [==============================] - 0s 7ms/sample - loss: 1.0752 - mean_squared_error: 1.0752
# loss= 1.075191903114319
# mse= 1.0751919
